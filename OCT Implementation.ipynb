# %% [markdown]
# # OCT Alpha Tuning Problem

# %% [markdown]
# ## Guidance on Using the OCT Package
#
# The **Optimal Classification Tree (OCT)** is an interpretable decision tree model formulated as a mixed-integer programming (MIP) problem. It determines the optimal splits by solving an optimization problem over the tree’s structure, using warm-start values from a Classification and Regression Tree (CART) to initialize the split decision variables (`a`) and thresholds (`b`).
#
# The `optimal_classification_tree` package implements key functions for training the OCT and data preprocessing tools specifically for importing data from UCI Machine Learning Repository (such that there are no missing values and each column of data is normalized). This notebook demonstrates how to implement the OCT model and benchmark it against standard classifiers such as **CART**, **XGBoost**, and **Random Forest**.
#
# ---
#
# ### 1. Data Preparation
#
# Start by importing the relevant functions from the `optimal_classification_tree` package and other classification models. The OCT class function allows us to plot the tree structure when the package `graphvi` is installed and added to our system path. Specify the following:
# - `data_id`: the dataset ID from UCIMLREPO,
# - `k_folds`: the number of folds for cross-validation,
# - `D`: the depth of the OCT tree.
# - `n`: randomly extract n observations if the original dataset is too large.
#
# and Use the `oct_tts` class to import a dataset from the UCI Machine Learning Repository and create cross-validation folds.
#
# Example usage:
#
# ```python
# dt = oct_tts(data_id, k_folds,n)
# df_train = dt.df_train #train set: 50% of each k_folds splits.
# df_cal = dt.df_cal #calibration set: 25% of each split.
# df_test = dt.df_test #test set: 25% of each split.
# ```
#
# ### 2.Fitting the OCT Model
#
# The balanced OCT model (where each node is forced to split) can be fit on a training set as follows:
#
# ```python
# oct_model = bal_OCT(df_train[i], df_test[i], D)
# ```
# Arguments:
# - `df_train[i]`: the i-th training set,
# - `df_test[i]`: the i-th test set,
# - `D`: the tree depth.
#
# If no warm-start is provided, the function internally fits a CART tree and uses its splits to warm-start the optimization.
# To provide custom warm-starts:
# - `warmstart_a`: a list of length \( $2^D$ - 1 \), where each entry indicates the feature index used to split at a branch node.
# - `warmstart_b`: a list of threshold values for the chosen feature at each branch node.
#
# The OCT model can be fit on a training set as follows:
#
# ```python
# oct_model = OCT_Main(df_train[i], df_test[i], D, alpha)
# ```
#
# ### 3. Model Evaluation
# After training, evaluate the in-sample and out-of-sample classification accuracy
#
# ```python
# oct_model.oct_accuracy_train  # OCT in-sample accuracy
# oct_model.cart_accuracy_train # CART in-sample accuracy
# ```
# To visualize the tree structure, use the following (requires Graphviz installed and configured on your system path):
# ```python
# oct_model.plot_tree_structure()
# ```
#
# More conveniently, one may choose to calibrate $\alpha$ by cross validation through setting `tuning_problem = 0` or calibrate $C$ by cross validation through setting `tuning_problem = 1` or simply training the balanced OCT model (where in this case, tuning_problem = None) and view the prediction accuracies by calling the following function:
# ```python
# OCT(data_id,D,k_folds,n=None,tuning_problem=None,alpha=None)
# ```
#
# ### 4. Benchmarking with Other Classifiers
# This notebook also benchmarks the OCT against XGBoost and Random Forest classifiers using the same cross-validation splits.
# Refer to the corresponding sections of the notebook for details on training and evaluating these models.

# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np

from optimal_classification_tree import oct_tts, bal_OCT,OCT_Main,OCT_AT_Sub,OCT

from graphviz import Digraph
import xgboost as xgb

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

data_id = 244
k_folds = 5
D=2

dt = oct_tts(data_id, k_folds)
df_train = dt.df_train
df_cal = dt.df_cal
df_test = dt.df_test

# %% [markdown]
# ### OCT vs. CART

# %%
OCT(data_id, D,k_folds,tuning_problem=1)
# Out:
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4867 nonzeros
# Model fingerprint: 0x331ceb6f
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 484 rows and 191 columns
# Presolve time: 0.01s
# Presolved: 215 rows, 70 columns, 1188 nonzeros
# Variable types: 0 continuous, 70 integer (65 binary)
# Found heuristic solution: objective 3.1914894
#
# Root relaxation: objective 0.000000e+00, 39 iterations, 0.00 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    3    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   23    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   23    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   13    3.19149    0.00000   100%     -    0s
#      0     0    1.06383    0   26    3.19149    1.06383  66.7%     -    0s
#      0     0    3.19149    0    5    3.19149    3.19149  0.00%     -    0s
#
# Cutting planes:
#   Learned: 61
#   Cover: 26
#   Implied bound: 2
#   Clique: 2
#   MIR: 16
#   StrongCG: 2
#   GUB cover: 13
#   Mod-K: 1
#   RLT: 2
#   Relax-and-lift: 15
#
# Explored 1 nodes (842 simplex iterations) in 0.14 seconds (0.05 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 3.19149
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.191489361702e+00, best bound 3.191489361702e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4859 nonzeros
# Model fingerprint: 0x718f086a
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start produced solution with objective 5.55556 (0.01s)
# Loaded user MIP start with objective 5.55556
#
# Presolve removed 483 rows and 190 columns
# Presolve time: 0.00s
# Presolved: 216 rows, 71 columns, 1180 nonzeros
# Variable types: 0 continuous, 71 integer (65 binary)
#
# Root relaxation: objective 0.000000e+00, 55 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   28    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   38    5.55556    0.00000   100%     -    0s
#      0     0    2.22226    0   11    5.55556    2.22226  60.0%     -    0s
#      0     0    3.33820    0    3    5.55556    3.33820  39.9%     -    0s
#      0     2    3.33820    0    3    5.55556    3.33820  39.9%     -    0s
#
# Cutting planes:
#   Learned: 78
#   Cover: 54
#   Clique: 8
#   MIR: 2
#   StrongCG: 1
#   GUB cover: 1
#
# Explored 38 nodes (1611 simplex iterations) in 0.18 seconds (0.07 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 5.55556
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.555555555556e+00, best bound 5.555555555556e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4811 nonzeros
# Model fingerprint: 0xc87289c1
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start produced solution with objective 6.81818 (0.02s)
# Loaded user MIP start with objective 6.81818
#
# Presolve removed 483 rows and 190 columns
# Presolve time: 0.00s
# Presolved: 216 rows, 71 columns, 1169 nonzeros
# Variable types: 0 continuous, 71 integer (65 binary)
#
# Root relaxation: objective 0.000000e+00, 42 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    8    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   45    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   38    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   43    6.81818    0.00000   100%     -    0s
#      0     0    3.40913    0   29    6.81818    3.40913  50.0%     -    0s
#      0     0    6.81818    0   26    6.81818    6.81818  0.00%     -    0s
#
# Cutting planes:
#   Learned: 17
#   Cover: 10
#   Clique: 1
#   MIR: 3
#   RLT: 1
#
# Explored 1 nodes (577 simplex iterations) in 0.12 seconds (0.05 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 6.81818
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.818181818182e+00, best bound 6.818181818182e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4859 nonzeros
# Model fingerprint: 0x61db8382
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 483 rows and 190 columns
# Presolve time: 0.01s
# Presolved: 216 rows, 71 columns, 1183 nonzeros
# Variable types: 0 continuous, 71 integer (65 binary)
# Found heuristic solution: objective 6.8181818
#
# Root relaxation: objective 0.000000e+00, 48 iterations, 0.00 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    8    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   31    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   33    6.81818    0.00000   100%     -    0s
#      0     0    0.01226    0    4    6.81818    0.01226   100%     -    0s
#      0     0    2.27273    0   19    6.81818    2.27273  66.7%     -    0s
#      0     0    2.35648    0   29    6.81818    2.35648  65.4%     -    0s
#      0     0    6.81818    0   10    6.81818    6.81818  0.00%     -    0s
#
# Cutting planes:
#   Learned: 57
#   Gomory: 4
#   Cover: 55
#   Clique: 8
#   MIR: 38
#   StrongCG: 1
#   GUB cover: 13
#   RLT: 1
#   Relax-and-lift: 2
#
# Explored 1 nodes (778 simplex iterations) in 0.15 seconds (0.06 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 6.81818
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.818181818182e+00, best bound 6.818181818182e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4843 nonzeros
# Model fingerprint: 0x593b53f1
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start produced solution with objective 5.55556 (0.01s)
# Loaded user MIP start with objective 5.55556
#
# Presolve removed 483 rows and 190 columns
# Presolve time: 0.01s
# Presolved: 216 rows, 71 columns, 1178 nonzeros
# Variable types: 0 continuous, 71 integer (65 binary)
#
# Root relaxation: objective 0.000000e+00, 44 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    3    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   25    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   27    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0    8    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   11    5.55556    0.00000   100%     -    0s
#      0     0    0.97227    0   11    5.55556    0.97227  82.5%     -    0s
#      0     0    1.54461    0   28    5.55556    1.54461  72.2%     -    0s
#
# Cutting planes:
#   Learned: 56
#   Cover: 42
#   Implied bound: 1
#   Clique: 2
#   MIR: 8
#   StrongCG: 2
#   Relax-and-lift: 1
#
# Explored 1 nodes (681 simplex iterations) in 0.11 seconds (0.05 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 5.55556
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.555555555556e+00, best bound 5.555555555556e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4867 nonzeros
# Model fingerprint: 0x55aa9dde
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 12 rows and 6 columns
# Presolve time: 0.01s
# Presolved: 687 rows, 255 columns, 4461 nonzeros
# Variable types: 0 continuous, 255 integer (240 binary)
# Found heuristic solution: objective 3.1914894
#
# Root relaxation: objective 0.000000e+00, 140 iterations, 0.00 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0  108    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   53    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   21    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0  100    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   14    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   33    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   12    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   12    3.19149    0.00000   100%     -    0s
#      0     2    0.00000    0   12    3.19149    0.00000   100%     -    0s
#
# Cutting planes:
#   Learned: 309
#   Gomory: 8
#   Lift-and-project: 1
#   Cover: 1733
#   Implied bound: 45
#   Clique: 7
#   MIR: 61
#   StrongCG: 5
#   GUB cover: 11
#   Inf proof: 38
#   Mod-K: 1
#   Network: 1
#   RLT: 6
#   Relax-and-lift: 33
#   BQP: 1
#
# Explored 12026 nodes (467580 simplex iterations) in 3.06 seconds (3.54 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 3.19149
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.191489361702e+00, best bound 3.191489361702e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4859 nonzeros
# Model fingerprint: 0xcde17371
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start produced solution with objective 5.55556 (0.01s)
# Loaded user MIP start with objective 5.55556
#
# Presolve removed 8 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 691 rows, 259 columns, 4453 nonzeros
# Variable types: 0 continuous, 259 integer (240 binary)
#
# Root relaxation: objective 0.000000e+00, 157 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0  101    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   84    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0    4    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   22    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0    8    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0    8    5.55556    0.00000   100%     -    0s
#      0     2    0.00000    0    8    5.55556    0.00000   100%     -    0s
# H 1759   426                       3.3333333    0.00000   100%  32.4    0s
#
# Cutting planes:
#   Learned: 346
#   Gomory: 35
#   Cover: 1033
#   Implied bound: 28
#   MIR: 35
#   StrongCG: 14
#   GUB cover: 11
#   Inf proof: 76
#   RLT: 2
#   Relax-and-lift: 14
#
# Explored 4602 nodes (137819 simplex iterations) in 1.28 seconds (1.17 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 3.33333 5.55556
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.333333333333e+00, best bound 3.333333333333e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4811 nonzeros
# Model fingerprint: 0x06d4d950
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start produced solution with objective 6.81818 (0.00s)
# Loaded user MIP start with objective 6.81818
#
# Presolve removed 8 rows and 2 columns
# Presolve time: 0.02s
# Presolved: 691 rows, 259 columns, 4409 nonzeros
# Variable types: 0 continuous, 259 integer (240 binary)
#
# Root relaxation: objective 0.000000e+00, 165 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    5    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   58    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   61    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   20    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   15    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   15    6.81818    0.00000   100%     -    0s
#      0     2    0.00000    0   15    6.81818    0.00000   100%     -    0s
#
# Cutting planes:
#   Learned: 457
#   Gomory: 18
#   Lift-and-project: 2
#   Cover: 1775
#   Implied bound: 387
#   Clique: 8
#   MIR: 20
#   StrongCG: 3
#   Flow cover: 6
#   GUB cover: 6
#   Inf proof: 54
#   RLT: 2
#   Relax-and-lift: 15
#   BQP: 21
#
# Explored 19374 nodes (606483 simplex iterations) in 4.63 seconds (5.23 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 6.81818
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.818181818182e+00, best bound 6.818181818182e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4859 nonzeros
# Model fingerprint: 0xed4e4def
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 8 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 691 rows, 259 columns, 4461 nonzeros
# Variable types: 0 continuous, 259 integer (240 binary)
# Found heuristic solution: objective 6.8181818
#
# Root relaxation: objective 0.000000e+00, 156 iterations, 0.00 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    5    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   79    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   76    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   16    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   32    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   24    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0    7    6.81818    0.00000   100%     -    0s
#      0     2    0.00000    0    7    6.81818    0.00000   100%     -    0s
#
# Cutting planes:
#   Learned: 433
#   Gomory: 41
#   Cover: 1674
#   Implied bound: 28
#   Clique: 30
#   MIR: 63
#   StrongCG: 6
#   GUB cover: 27
#   Inf proof: 52
#   Network: 2
#   RLT: 1
#   Relax-and-lift: 28
#
# Explored 11731 nodes (258686 simplex iterations) in 2.89 seconds (3.16 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 6.81818
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.818181818182e+00, best bound 6.818181818182e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4843 nonzeros
# Model fingerprint: 0xf104eb25
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 8 rows and 2 columns
# Presolve time: 0.01s
# Presolved: 691 rows, 259 columns, 4441 nonzeros
# Variable types: 0 continuous, 259 integer (240 binary)
# Found heuristic solution: objective 5.5555556
#
# Root relaxation: objective 0.000000e+00, 128 iterations, 0.00 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    3    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   32    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   39    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   13    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0  112    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   21    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   30    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   10    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0    8    5.55556    0.00000   100%     -    0s
#      0     2    0.00000    0    8    5.55556    0.00000   100%     -    0s
# * 3903   542              14       4.4444444    0.05697  98.7%  33.5    1s
#
# Cutting planes:
#   Learned: 293
#   Gomory: 9
#   Cover: 1384
#   Implied bound: 24
#   Clique: 16
#   MIR: 134
#   StrongCG: 21
#   Flow cover: 16
#   GUB cover: 16
#   Inf proof: 73
#   Zero half: 1
#   RLT: 3
#   Relax-and-lift: 35
#   BQP: 1
#
# Explored 6851 nodes (200657 simplex iterations) in 1.72 seconds (1.76 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 4.44444 5.55556
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.444444444444e+00, best bound 4.444444444444e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4867 nonzeros
# Model fingerprint: 0xe9ffc844
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 14 rows and 7 columns
# Presolve time: 0.01s
# Presolved: 685 rows, 254 columns, 4443 nonzeros
# Variable types: 0 continuous, 254 integer (239 binary)
# Found heuristic solution: objective 3.1914894
#
# Root relaxation: objective 0.000000e+00, 105 iterations, 0.01 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   55    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   60    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   14    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   10    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   15    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   12    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0  104    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   15    3.19149    0.00000   100%     -    0s
#      0     0    0.00000    0   15    3.19149    0.00000   100%     -    0s
#      0     2    0.00000    0   15    3.19149    0.00000   100%     -    0s
# * 3322   934              19       2.1276702    0.00000   100%  41.5    1s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 63
#   Implied bound: 1
#   Clique: 1
#   MIR: 6
#   StrongCG: 2
#   Flow cover: 34
#   GUB cover: 6
#   Inf proof: 8
#
# Explored 9436 nodes (358232 simplex iterations) in 3.17 seconds (3.10 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 2.12767 3.19149
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.127670209791e+00, best bound 2.127659574468e+00, gap 0.0005%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4859 nonzeros
# Model fingerprint: 0xba5a36e1
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 10 rows and 3 columns
# Presolve time: 0.02s
# Presolved: 689 rows, 258 columns, 4427 nonzeros
# Variable types: 0 continuous, 258 integer (239 binary)
# Found heuristic solution: objective 5.5555556
#
# Root relaxation: objective 0.000000e+00, 119 iterations, 0.00 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   67    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   72    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   11    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   56    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   22    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   22    5.55556    0.00000   100%     -    0s
#      0     2    0.00000    0   15    5.55556    0.00000   100%     -    0s
# * 2604   988              22       4.4444444    0.00000   100%  33.3    0s
# H 6426  1578                       3.3333333    0.00000   100%   3.5    2s
#
# Cutting planes:
#   Learned: 3
#   Gomory: 1
#   Cover: 57
#   MIR: 5
#   StrongCG: 1
#   Flow cover: 31
#   GUB cover: 13
#   Inf proof: 22
#   RLT: 1
#   Relax-and-lift: 4
#   PSD: 1
#
# Explored 8421 nodes (339455 simplex iterations) in 3.24 seconds (3.03 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 3: 3.33333 4.44444 5.55556
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.333333333333e+00, best bound 3.333333333333e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4811 nonzeros
# Model fingerprint: 0x8490a4df
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 10 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 689 rows, 258 columns, 4383 nonzeros
# Variable types: 0 continuous, 258 integer (239 binary)
# Found heuristic solution: objective 6.8181818
#
# Root relaxation: objective 0.000000e+00, 134 iterations, 0.00 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   72    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   80    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   12    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   16    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   23    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   35    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   12    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   34    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   21    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   98    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   34    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   19    6.81818    0.00000   100%     -    0s
#      0     2    0.00000    0    5    6.81818    0.00000   100%     -    0s
#  18980  1765     cutoff   33         6.81818    2.27273  66.7%  20.4    5s
#
# Cutting planes:
#   Learned: 91
#   Gomory: 3
#   Cover: 92
#   Clique: 1
#   MIR: 15
#   StrongCG: 1
#   Flow cover: 10
#   GUB cover: 5
#   Inf proof: 20
#   Relax-and-lift: 14
#   BQP: 9
#
# Explored 27557 nodes (735718 simplex iterations) in 5.68 seconds (4.73 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 6.81818
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.818181818182e+00, best bound 6.818181818182e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4859 nonzeros
# Model fingerprint: 0xebd61761
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 10 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 689 rows, 258 columns, 4439 nonzeros
# Variable types: 0 continuous, 258 integer (239 binary)
# Found heuristic solution: objective 6.8181818
#
# Root relaxation: objective 0.000000e+00, 125 iterations, 0.00 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   75    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   79    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0    8    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0    8    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   34    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   20    6.81818    0.00000   100%     -    0s
#      0     0    0.00000    0   20    6.81818    0.00000   100%     -    0s
#      0     2    0.00000    0   20    6.81818    0.00000   100%     -    0s
#  16063   247    4.54545   32   21    6.81818    2.27273  66.7%  18.3    5s
#
# Cutting planes:
#   Learned: 2
#   Cover: 76
#   Clique: 2
#   MIR: 12
#   StrongCG: 1
#   Flow cover: 15
#   GUB cover: 4
#   Inf proof: 17
#   RLT: 1
#   Relax-and-lift: 7
#   BQP: 2
#   PSD: 2
#
# Explored 17067 nodes (516896 simplex iterations) in 5.18 seconds (4.44 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 6.81818
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.818181818182e+00, best bound 6.818181818182e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 699 rows, 261 columns and 4843 nonzeros
# Model fingerprint: 0x0261b25e
# Variable types: 7 continuous, 254 integer (242 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 5e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 5e+01]
#
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 10 rows and 3 columns
# Presolve time: 0.01s
# Presolved: 689 rows, 258 columns, 4419 nonzeros
# Variable types: 0 continuous, 258 integer (239 binary)
# Found heuristic solution: objective 5.5555556
#
# Root relaxation: objective 0.000000e+00, 138 iterations, 0.00 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   55    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   56    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   11    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0   16    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0    7    5.55556    0.00000   100%     -    0s
#      0     0    0.00000    0    7    5.55556    0.00000   100%     -    0s
#      0     2    0.00000    0    7    5.55556    0.00000   100%     -    0s
# H 3076   880                       4.4444444    0.00000   100%  35.3    1s
#  15019   820    1.11111   26   45    4.44444    1.11111  75.0%  37.7    5s
#
# Cutting planes:
#   Learned: 3
#
# Explored 26548 nodes (939100 simplex iterations) in 6.76 seconds (6.81 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 2: 4.44444 5.55556
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.444444444444e+00, best bound 4.444444444444e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 1024 rows, 361 columns and 7187 nonzeros
# Model fingerprint: 0x3fcd1a67
# Variable types: 7 continuous, 354 integer (342 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 8e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
#
# Warning: Completing partial solution with 327 unfixed non-continuous variables out of 354
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 708 rows and 265 columns
# Presolve time: 0.00s
# Presolved: 316 rows, 96 columns, 1740 nonzeros
# Variable types: 0 continuous, 96 integer (90 binary)
# Found heuristic solution: objective 6.5217391
#
# Root relaxation: objective 0.000000e+00, 80 iterations, 0.01 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    6.52174    0.00000   100%     -    0s
#      0     0    0.00000    0    8    6.52174    0.00000   100%     -    0s
#      0     0    0.00000    0   10    6.52174    0.00000   100%     -    0s
#      0     0    0.00000    0    7    6.52174    0.00000   100%     -    0s
#      0     0    0.00000    0    7    6.52174    0.00000   100%     -    0s
#      0     2    0.00000    0    7    6.52174    0.00000   100%     -    0s
#
# Cutting planes:
#   Learned: 86
#   Cover: 37
#   Implied bound: 1
#   Clique: 16
#   StrongCG: 1
#   Relax-and-lift: 16
#
# Explored 83 nodes (1925 simplex iterations) in 0.18 seconds (0.08 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 6.52174
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.521739130435e+00, best bound 6.521739130435e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 1024 rows, 361 columns and 7251 nonzeros
# Model fingerprint: 0xe12b4a0d
# Variable types: 7 continuous, 354 integer (342 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 8e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
#
# Warning: Completing partial solution with 327 unfixed non-continuous variables out of 354
# User MIP start did not produce a new incumbent solution
#
# Presolve removed 708 rows and 265 columns
# Presolve time: 0.01s
# Presolved: 316 rows, 96 columns, 1753 nonzeros
# Variable types: 0 continuous, 96 integer (90 binary)
# Found heuristic solution: objective 10.2272727
#
# Root relaxation: objective 0.000000e+00, 53 iterations, 0.00 seconds (0.00 work units)
# Another try with MIP start
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0   10   10.22727    0.00000   100%     -    0s
#      0     0    0.00000    0   48   10.22727    0.00000   100%     -    0s
#      0     0    0.00000    0   30   10.22727    0.00000   100%     -    0s
#      0     0    0.00000    0    7   10.22727    0.00000   100%     -    0s
#      0     0    0.00000    0   19   10.22727    0.00000   100%     -    0s
#      0     0    0.00000    0    8   10.22727    0.00000   100%     -    0s
#      0     0    0.00000    0   33   10.22727    0.00000   100%     -    0s
#      0     0    4.54545    0   27   10.22727    4.54545  55.6%     -    0s
#      0     0    6.81818    0   13   10.22727    6.81818  33.3%     -    0s
#      0     0   10.22727    0   42   10.22727   10.22727  0.00%     -    0s
#
# Cutting planes:
#   Learned: 64
#   Cover: 51
#   Implied bound: 1
#   Clique: 5
#   MIR: 10
#   GUB cover: 6
#   Relax-and-lift: 14
#
# Explored 1 nodes (1724 simplex iterations) in 0.22 seconds (0.10 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 10.2273
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.022727272727e+01, best bound 1.022727272727e+01, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 1024 rows, 361 columns and 7243 nonzeros
# Model fingerprint: 0x91fd29fd
# Variable types: 7 continuous, 354 integer (342 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 8e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
#
# Warning: Completing partial solution with 327 unfixed non-continuous variables out of 354
# User MIP start produced solution with objective 11.5385 (0.01s)
# Loaded user MIP start with objective 11.5385
#
# Presolve removed 708 rows and 265 columns
# Presolve time: 0.00s
# Presolved: 316 rows, 96 columns, 1756 nonzeros
# Variable types: 0 continuous, 96 integer (90 binary)
#
# Root relaxation: objective 0.000000e+00, 70 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    6   11.53846    0.00000   100%     -    0s
#      0     0    0.00000    0   17   11.53846    0.00000   100%     -    0s
#      0     0    0.00000    0   24   11.53846    0.00000   100%     -    0s
#      0     0    1.15385    0    6   11.53846    1.15385  90.0%     -    0s
#      0     0    1.15385    0    6   11.53846    1.15385  90.0%     -    0s
#      0     2    1.15385    0    6   11.53846    1.15385  90.0%     -    0s
#
# Cutting planes:
#   Learned: 228
#   Gomory: 7
#   Cover: 184
#   Implied bound: 1
#   Clique: 3
#   MIR: 9
#   StrongCG: 3
#   GUB cover: 6
#   Inf proof: 2
#   Mod-K: 3
#   Relax-and-lift: 20
#
# Explored 1148 nodes (20788 simplex iterations) in 0.36 seconds (0.19 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 11.5385
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.153846153846e+01, best bound 1.153846153846e+01, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 1024 rows, 361 columns and 7227 nonzeros
# Model fingerprint: 0x43a9b7c8
# Variable types: 7 continuous, 354 integer (342 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 8e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
#
# Warning: Completing partial solution with 327 unfixed non-continuous variables out of 354
# User MIP start produced solution with objective 8.95522 (0.01s)
# Loaded user MIP start with objective 8.95522
#
# Presolve removed 708 rows and 265 columns
# Presolve time: 0.01s
# Presolved: 316 rows, 96 columns, 1748 nonzeros
# Variable types: 0 continuous, 96 integer (90 binary)
#
# Root relaxation: objective 0.000000e+00, 62 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    2    8.95522    0.00000   100%     -    0s
#      0     0    0.00000    0   12    8.95522    0.00000   100%     -    0s
#      0     0    0.00000    0   10    8.95522    0.00000   100%     -    0s
#      0     0    0.00000    0   10    8.95522    0.00000   100%     -    0s
#      0     0    0.00000    0   44    8.95522    0.00000   100%     -    0s
#      0     0    8.95522    0   22    8.95522    8.95522  0.00%     -    0s
#
# Cutting planes:
#   Learned: 190
#   Cover: 49
#   MIR: 21
#   Zero half: 2
#   RLT: 1
#   Relax-and-lift: 13
#
# Explored 1 nodes (1796 simplex iterations) in 0.17 seconds (0.08 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 8.95522
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.955223880597e+00, best bound 8.955223880597e+00, gap 0.0000%
# Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (win64 - Windows 11.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 9 185H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 1024 rows, 361 columns and 7259 nonzeros
# Model fingerprint: 0x6ec6eb03
# Variable types: 7 continuous, 354 integer (342 binary)
# Coefficient statistics:
#   Matrix range     [6e-02, 8e+01]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 8e+01]
#
# Warning: Completing partial solution with 327 unfixed non-continuous variables out of 354
# User MIP start produced solution with objective 7.72059 (0.01s)
# Loaded user MIP start with objective 7.72059
#
# Presolve removed 708 rows and 265 columns
# Presolve time: 0.01s
# Presolved: 316 rows, 96 columns, 1753 nonzeros
# Variable types: 0 continuous, 96 integer (90 binary)
#
# Root relaxation: objective 0.000000e+00, 56 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    0.00000    0    8    7.72059    0.00000   100%     -    0s
#      0     0    0.00000    0   25    7.72059    0.00000   100%     -    0s
#      0     0    0.00000    0   46    7.72059    0.00000   100%     -    0s
#      0     0    3.40913    0    9    7.72059    3.40913  55.8%     -    0s
#      0     0    3.75092    0    9    7.72059    3.75092  51.4%     -    0s
#      0     2    3.75092    0    9    7.72059    3.75092  51.4%     -    0s
#
# Cutting planes:
#   Learned: 128
#   Gomory: 1
#   Cover: 116
#   Clique: 22
#   MIR: 6
#   GUB cover: 25
#   Inf proof: 1
#   Zero half: 1
#   Relax-and-lift: 1
#
# Explored 193 nodes (4602 simplex iterations) in 0.23 seconds (0.11 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 1: 7.72059
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.720588235294e+00, best bound 7.720588235294e+00, gap 0.0000%
# {'C_opt': 1,
#  'OCT_train_accuracy': np.float64(0.8933333333333333),
#  'OCT_test_accuracy': np.float64(0.8400000000000001),
#  'CART_train_accuracy': 0.8986666666666666,
#  'CART_test_accuracy': 0.8240000000000001}

# %% [markdown]
# ### XGBoost and Random Forest

# %%
xgboost_in = []
xgboost_out = []
rf_in = []
rf_out = []
for i in range(k_folds):  
    train = pd.concat([df_train[i], df_cal[i]], ignore_index=True).reset_index(drop=True)
    test = df_test[i].reset_index(drop=True)
    x_train = train.drop(['target'], axis=1)
    y_train = train['target'].astype('int')
    x_test = test.drop(['target'], axis=1)
    y_test = test['target'].astype('int')
    
    k = len(y_train.unique())
    if k >= 3:
        model_xgb = xgb.XGBClassifier(objective='multi:softmax',num_class=k,use_label_encoder=False, max_depth=D)
    else:
        model_xgb = xgb.XGBClassifier(objective='binary:logistic',use_label_encoder=False, max_depth=D)
    model_xgb.fit(x_train, y_train)

    y_fit_xgb = model_xgb.predict(x_train)
    y_pred_xgb = model_xgb.predict(x_test)
    xgboost_in.append(accuracy_score(y_train, y_fit_xgb))
    xgboost_out.append(accuracy_score(y_test, y_pred_xgb))
    
    model_rf = RandomForestClassifier(n_estimators=100, random_state=42,max_depth=D) #build 100 decision trees
    model_rf.fit(x_train, y_train)
    y_fit_rf = model_rf.predict(x_train)
    y_pred_rf = model_rf.predict(x_test)
    rf_in.append(accuracy_score(y_train, y_fit_rf))
    rf_out.append(accuracy_score(y_test, y_pred_rf))

results = {
    'xgboost_in': float(np.mean(xgboost_in)),
    'xgboost_out': float(np.mean(xgboost_out)),
    'rf_in': float(np.mean(rf_in)),
    'rf_out': float(np.mean(rf_out))
}

results
# Out:
# {'xgboost_in': 0.9706666666666667,
#  'xgboost_out': 0.8160000000000001,
#  'rf_in': 0.8933333333333333,
#  'rf_out': 0.8400000000000001}
